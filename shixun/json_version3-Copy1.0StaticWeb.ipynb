# %%
#高考帮：url爬取结合爬虫。version3.0最终版。
import requests
from bs4 import BeautifulSoup
from lxml import etree
#import pymysql
import json
import urllib3.request
from collections import OrderedDict
#import httplib
from queue import Queue
import re

# %%
ini_url= "http://college.gaokao.com/spepoint/y2011"
URL_JFK = 'http://211.87.230.55:8080'

# %%
filename = '/User/ZJX/Desktop/url.txt'

# %%
ini_r = requests.get(ini_url)
ini_html = ini_r.text

# %%
ini_s = etree.HTML(ini_html)
ini_content = ini_s.xpath('//*[@id="wrapper"]/div[1]/p[3]/a//@href')
#print(ini_content)

# %%
queueYear = Queue()
queueLast = Queue()

# %%
#print('0')
for i in range(1,len(ini_content)):
    print(i,ini_content[i])
    queueYear.put(ini_content[i])
    #print('0')
# Out:
# 1 http://college.gaokao.com/spepoint/y2018/
# 2 http://college.gaokao.com/spepoint/y2017/
# 3 http://college.gaokao.com/spepoint/y2016/
# 4 http://college.gaokao.com/spepoint/y2015/
# 5 http://college.gaokao.com/spepoint/y2014/
# 6 http://college.gaokao.com/spepoint/y2013/
# 7 http://college.gaokao.com/spepoint/y2012/
# 8 http://college.gaokao.com/spepoint/y2011/
# 9 http://college.gaokao.com/spepoint/y2010/
# 10 http://college.gaokao.com/spepoint/y2009/
# 11 http://college.gaokao.com/spepoint/y2008/
# 12 http://college.gaokao.com/spepoint/y2007/

# %%
while not queueYear.empty():
    
    #nexturl是不同年份，全部省份，全部文理分科的url
    nexturl = queueYear.get()
    
    next_r = requests.get(nexturl)
    next_html = next_r.text
    next_s = etree.HTML(next_html)
    #获得每个年份的末页
    next_content = next_s.xpath('//*[@id="wrapper"]/div[4]/ul/li[4]/a//@href')
    print(next_content)
    
    if next_content:
        #print(next_content[0])
        queueLast.put(next_content[0])
    
print(queueLast)
# Out:
# []
# []
# ['http://college.gaokao.com/spepoint/y2016/p864/']
# []
# ['http://college.gaokao.com/spepoint/y2014/p5/']
# ['http://college.gaokao.com/spepoint/y2013/p12466/']
# ['http://college.gaokao.com/spepoint/y2012/p10277/']
# ['http://college.gaokao.com/spepoint/y2011/p12426/']
# ['http://college.gaokao.com/spepoint/y2010/p9396/']
# ['http://college.gaokao.com/spepoint/y2009/p10956/']
# ['http://college.gaokao.com/spepoint/y2008/p5838/']
# ['http://college.gaokao.com/spepoint/y2007/p5485/']
# <queue.Queue object at 0x1081963c8>

# %%
#暂停后重跑，一年一年的来
url = queueLast.get()
print(url)
# Out:
# http://college.gaokao.com/spepoint/y2013/p12466/

# %%
while not queueLast.empty():
    lasturl = queueLast.get()
    matchObj1 = re.match(r'(http://college.gaokao.com/spepoint/y\d+/p)(\d+)/',lasturl, re.M | re.U)
    
    url_model = matchObj1.group(1)
    pagenum = matchObj1.group(2)
    
    
    print("\nurl_model output:   ",url_model)
    print("\pagenum output:   ",pagenum)
    
    #eg. http://college.gaokao.com/spepoint/y2012/p10277/
    #//*[@id="wrapper"]/div[1]/p[3]/a
    
    
    
    for i in range(9700,int(pagenum)+1):#5770
        url = url_model+str(i)
        r = requests.get(url)
        html = r.text
        
        ret=[]
        
        
        s=etree.HTML(html)
        
        xpath0 = '//*[@id="wrapper"]/div[4]/table/tr'
        majorPath = '/td[1]//text()'
        schoolPath = '/td[2]//text()'
        avscorePath = '/td[3]//text()'
        hiscorePath = '/td[4]//text()'
        provincePath = '/td[5]//text()'
        subjectPath = '/td[6]//text()'
        yearPath = '/td[7]//text()'
        piciPath = '/td[8]//text()'
        
        
        #content = s.xpath('//*[@id="wrapper"]/div[4]/table/tr/td[position()<9]//text()')
        count_xpath = xpath0+yearPath
        for_count = s.xpath(count_xpath)
        count = len(for_count)
        
        
        for j in range(count):
            lmajor = s.xpath(xpath0+'['+str(j+2)+']'+majorPath)
            if len(lmajor)!=0:
                major = lmajor[0]
            else:
                major = None
                
            lschool = s.xpath(xpath0+'['+str(j+2)+']'+schoolPath)
            if len(lschool)!=0:
                school = lschool[0]
            else:
                school = None
                
            lav_score = s.xpath(xpath0+'['+str(j+2)+']'+avscorePath)
            if len(lav_score)!=0:
                av_score = lav_score[0]
            else:
                av_score = None
                
            lhi_score = s.xpath(xpath0+'['+str(j+2)+']'+hiscorePath)
            if len(lhi_score)!=0:
                hi_score = lhi_score[0]
            else:
                hi_score = None
                
            lstu_province = s.xpath(xpath0+'['+str(j+2)+']'+provincePath)
            if len(lstu_province)!=0:
                stu_province = lstu_province[0]
            else:
                stu_province = None
                
            lsubject = s.xpath(xpath0+'['+str(j+2)+']'+subjectPath)
            if len(lsubject)!=0:
                subject = lsubject[0]
            else:
                subject = None
                
            lyear = s.xpath(xpath0+'['+str(j+2)+']'+yearPath)
            if len(lyear)!=0:
                year = lyear[0]
            else:
                year = None
                
            lpici = s.xpath(xpath0+'['+str(j+2)+']'+piciPath)
            if len(lpici)!=0:
                pici = lpici[0]
            else:
                pici = None
            
            #print(major)
            #print(school)
            
            item = OrderedDict()
            item.clear()
            
            
            
            if school=="--" or school=="------" or school=='':
                school = None
                item['schoolName'] = school
            else:
                item['schoolName'] = school
             
            
            if stu_province=="--" or stu_province=="------" or stu_province=='':
                stu_province = None
                item['province'] = stu_province
            else:
                item['province'] = stu_province   
            
            
            if year=="--" or year=="------" or year=='':
                year = None
                item['year'] = year
            else:
                item['year'] = year
                
            
            if subject=="--" or subject=="------" or subject=='':
                subject = None
                item['category'] = subject
            else:
                item['category'] = subject
                
            
            if major=="--" or major=="------" or major=='':
                major = None
                item['major'] = major
            else:
                item['major'] = major
                
                
            if pici=="--" or pici=="------" or pici=='' or pici==None or pici=='-----':
                pici = "-"
                item['batch'] = pici
            else:
                item['batch'] = pici[1:]
            
            
            if av_score=="--" or av_score=="------" or av_score=='':
                av_score = None
                item['avegrade'] = av_score
            else:
                item['avegrade'] = av_score
                
            
            if hi_score=="--" or hi_score=="------" or hi_score=='':
                hi_score = None
                item['maxgrade'] = hi_score
            else:
                item['maxgrade'] = hi_score
                
            
            
            
            #item['school_name'] = school
            #item['province'] = stu_province
            #item['year'] = year
            #item['category'] = subject
            #item['major'] = major
            #item['batch'] = pici
            #item['avegrade'] = av_score
            #item['maxgrade'] = hi_score
            
            item['mingrade'] = None
            
            
            ret.append(item)
        
        data = {'cutoffs':ret}
        json_str = json.dumps(data,ensure_ascii=False)
        
        print("页数：",i)
        #print(json_str)
        
        headers = {'Content-Type':'application/json'}
        request = requests.post(URL_JFK+"/addCutoff", data=json_str.encode('utf-8'), headers=headers)
# Out:
# url_model output:    http://college.gaokao.com/spepoint/y2012/p
# \pagenum output:    10277
# 页数： 9700
# 页数： 9701
# 页数： 9702
# 页数： 9703
# 页数： 9704
# 页数： 9705
# 页数： 9706
# 页数： 9707
# 页数： 9708
# 页数： 9709
# 页数： 9710
# 页数： 9711
# 页数： 9712
# 页数： 9713
# 页数： 9714
# 页数： 9715
# 页数： 9716
# 页数： 9717
# 页数： 9718
# 页数： 9719
# 页数： 9720
# 页数： 9721
# 页数： 9722
# 页数： 9723
# 页数： 9724
# 页数： 9725
# 页数： 9726
# 页数： 9727
# 页数： 9728
# 页数： 9729
# 页数： 9730
# 页数： 9731
# 页数： 9732
# 页数： 9733
# 页数： 9734
# 页数： 9735
# 页数： 9736
# 页数： 9737
# 页数： 9738
# 页数： 9739
# 页数： 9740
# 页数： 9741
# 页数： 9742
# 页数： 9743
# 页数： 9744
# 页数： 9745
# 页数： 9746
# 页数： 9747
# 页数： 9748
# 页数： 9749
# 页数： 9750
# 页数： 9751
# 页数： 9752
# 页数： 9753
# 页数： 9754
# 页数： 9755
# 页数： 9756
# 页数： 9757
# 页数： 9758
# 页数： 9759
# 页数： 9760
# 页数： 9761
# 页数： 9762
# 页数： 9763
# 页数： 9764
# 页数： 9765
# 页数： 9766
# 页数： 9767
# 页数： 9768
# 页数： 9769
# 页数： 9770
# 页数： 9771
# 页数： 9772
# 页数： 9773
# 页数： 9774
# 页数： 9775
# 页数： 9776
# 页数： 9777
# 页数： 9778
# 页数： 9779
# 页数： 9780
# 页数： 9781
# 页数： 9782
# 页数： 9783
# 页数： 9784
# 页数： 9785
# 页数： 9786
# 页数： 9787
# 页数： 9788
# 页数： 9789
# 页数： 9790
# 页数： 9791
# 页数： 9792
# 页数： 9793
# 页数： 9794
# 页数： 9795
# 页数： 9796
# 页数： 9797
# 页数： 9798
# 页数： 9799
# 页数： 9800
# 页数： 9801
# 页数： 9802
# 页数： 9803
# 页数： 9804
# 页数： 9805
# 页数： 9806
# 页数： 9807
# 页数： 9808
# 页数： 9809
# 页数： 9810
# 页数： 9811
# 页数： 9812
# 页数： 9813
# 页数： 9814
# 页数： 9815
# 页数： 9816
# 页数： 9817
# 页数： 9818
# 页数： 9819
# 页数： 9820
# 页数： 9821
# 页数： 9822
# 页数： 9823
# 页数： 9824
# 页数： 9825
# 页数： 9826
# 页数： 9827
# 页数： 9828
# 页数： 9829
# 页数： 9830
# 页数： 9831
# 页数： 9832
# 页数： 9833
# 页数： 9834
# 页数： 9835
# 页数： 9836
# 页数： 9837
# 页数： 9838
# 页数： 9839
# 页数： 9840
# 页数： 9841
# 页数： 9842
# 页数： 9843
# 页数： 9844
# 页数： 9845
# 页数： 9846
# 页数： 9847
# 页数： 9848
# 页数： 9849
# 页数： 9850
# 页数： 9851
# 页数： 9852
# 页数： 9853
# 页数： 9854
# 页数： 9855
# 页数： 9856
# 页数： 9857
# 页数： 9858
# 页数： 9859
# 页数： 9860
# 页数： 9861
# 页数： 9862
# 页数： 9863
# 页数： 9864
# 页数： 9865
# 页数： 9866
# 页数： 9867
# 页数： 9868
# 页数： 9869
# 页数： 9870
# 页数： 9871
# 页数： 9872
# 页数： 9873
# 页数： 9874
# 页数： 9875
# 页数： 9876
# 页数： 9877
# 页数： 9878
# 页数： 9879
# 页数： 9880
# 页数： 9881
# 页数： 9882
# 页数： 9883
# 页数： 9884
# 页数： 9885
# 页数： 9886
# 页数： 9887
# 页数： 9888
# 页数： 9889
# 页数： 9890
# 页数： 9891
# 页数： 9892
# 页数： 9893
# 页数： 9894
# 页数： 9895
# 页数： 9896
# 页数： 9897
# 页数： 9898
# 页数： 9899
# 页数： 9900
# 页数： 9901
# 页数： 9902
# 页数： 9903
# 页数： 9904
# 页数： 9905
# 页数： 9906
# 页数： 9907
# 页数： 9908
# 页数： 9909
# 页数： 9910
# 页数： 9911
# 页数： 9912
# 页数： 9913
# 页数： 9914
# 页数： 9915
# 页数： 9916
# 页数： 9917
# 页数： 9918
# 页数： 9919
# 页数： 9920
# 页数： 9921
# 页数： 9922
# 页数： 9923
# 页数： 9924
# 页数： 9925
# 页数： 9926
# 页数： 9927
# 页数： 9928
# 页数： 9929
# 页数： 9930
# 页数： 9931
# 页数： 9932
# 页数： 9933
# 页数： 9934
# 页数： 9935
# 页数： 9936
# 页数： 9937
# 页数： 9938
# 页数： 9939
# 页数： 9940
# 页数： 9941
# 页数： 9942
# 页数： 9943
# 页数： 9944
# 页数： 9945
# 页数： 9946
# 页数： 9947
# 页数： 9948
# 页数： 9949
# 页数： 9950
# 页数： 9951
# 页数： 9952
# 页数： 9953
# 页数： 9954
# 页数： 9955
# 页数： 9956
# 页数： 9957
# 页数： 9958
# 页数： 9959
# 页数： 9960
# 页数： 9961
# 页数： 9962
# 页数： 9963
# 页数： 9964
# 页数： 9965
# 页数： 9966
# 页数： 9967
# 页数： 9968
# 页数： 9969
# 页数： 9970
# 页数： 9971
# 页数： 9972
# 页数： 9973
# 页数： 9974
# 页数： 9975
# 页数： 9976
# 页数： 9977
# 页数： 9978
# 页数： 9979
# 页数： 9980
# 页数： 9981
# 页数： 9982
# 页数： 9983
# 页数： 9984
# 页数： 9985
# 页数： 9986
# 页数： 9987
# 页数： 9988
# 页数： 9989
# 页数： 9990
# 页数： 9991
# 页数： 9992
# 页数： 9993
# 页数： 9994
# 页数： 9995
# 页数： 9996
# 页数： 9997
# 页数： 9998
# 页数： 9999
# 页数： 10000
# 页数： 10001
# 页数： 10002
# 页数： 10003
# 页数： 10004
# 页数： 10005
# 页数： 10006
# 页数： 10007
# 页数： 10008
# 页数： 10009
# 页数： 10010
# 页数： 10011
# 页数： 10012
# 页数： 10013
# 页数： 10014
# 页数： 10015
# 页数： 10016
# 页数： 10017
# 页数： 10018
# 页数： 10019
# 页数： 10020
# 页数： 10021
# 页数： 10022
# 页数： 10023
# 页数： 10024
# 页数： 10025
# 页数： 10026
# 页数： 10027
# 页数： 10028
# 页数： 10029
# 页数： 10030
# 页数： 10031
# 页数： 10032
# 页数： 10033
# 页数： 10034
# 页数： 10035
# 页数： 10036
# 页数： 10037
# 页数： 10038
# 页数： 10039
# 页数： 10040
# 页数： 10041
# 页数： 10042
# 页数： 10043
# 页数： 10044
# 页数： 10045
# 页数： 10046
# 页数： 10047
# 页数： 10048
# 页数： 10049
# 页数： 10050
# 页数： 10051
# 页数： 10052
# 页数： 10053
# 页数： 10054
# 页数： 10055
# 页数： 10056
# 页数： 10057
# 页数： 10058
# 页数： 10059
# 页数： 10060
# 页数： 10061
# 页数： 10062
# 页数： 10063
# 页数： 10064
# 页数： 10065
# 页数： 10066
# 页数： 10067
# 页数： 10068
# 页数： 10069
# 页数： 10070
# 页数： 10071
# 页数： 10072
# 页数： 10073
# 页数： 10074
# 页数： 10075
# 页数： 10076
# 页数： 10077
# 页数： 10078
# 页数： 10079
# 页数： 10080
# 页数： 10081
# 页数： 10082
# 页数： 10083
# 页数： 10084
# 页数： 10085
# 页数： 10086
# 页数： 10087
# 页数： 10088
# 页数： 10089
# 页数： 10090
# 页数： 10091
# 页数： 10092
# 页数： 10093
# 页数： 10094
# 页数： 10095
# 页数： 10096
# 页数： 10097
# 页数： 10098
# 页数： 10099
# 页数： 10100
# 页数： 10101
# 页数： 10102
# 页数： 10103
# 页数： 10104
# 页数： 10105
# 页数： 10106
# 页数： 10107
# 页数： 10108
# 页数： 10109
# 页数： 10110
# 页数： 10111
# 页数： 10112
# 页数： 10113
# 页数： 10114
# 页数： 10115
# 页数： 10116
# 页数： 10117
# 页数： 10118
# 页数： 10119
# 页数： 10120
# 页数： 10121
# 页数： 10122
# 页数： 10123
# 页数： 10124
# 页数： 10125
# 页数： 10126
# 页数： 10127
# 页数： 10128
# 页数： 10129
# 页数： 10130
# 页数： 10131
# 页数： 10132
# 页数： 10133
# 页数： 10134
# 页数： 10135
# 页数： 10136
# 页数： 10137
# 页数： 10138
# 页数： 10139
# 页数： 10140
# 页数： 10141
# 页数： 10142
# 页数： 10143
# 页数： 10144
# 页数： 10145
# 页数： 10146
# 页数： 10147
# 页数： 10148
# 页数： 10149
# 页数： 10150
# 页数： 10151
# 页数： 10152
# 页数： 10153
# 页数： 10154
# 页数： 10155
# 页数： 10156
# 页数： 10157
# 页数： 10158
# 页数： 10159
# 页数： 10160
# 页数： 10161
# 页数： 10162
# 页数： 10163
# 页数： 10164
# 页数： 10165
# 页数： 10166
# 页数： 10167
# 页数： 10168
# 页数： 10169
# 页数： 10170
# 页数： 10171
# 页数： 10172
# 页数： 10173
# 页数： 10174
# 页数： 10175
# 页数： 10176
# 页数： 10177
# 页数： 10178
# 页数： 10179
# 页数： 10180
# 页数： 10181
# 页数： 10182
# 页数： 10183
# 页数： 10184
# 页数： 10185
# 页数： 10186
# 页数： 10187
# 页数： 10188
# 页数： 10189
# 页数： 10190
# 页数： 10191
# 页数： 10192
# 页数： 10193
# 页数： 10194
# 页数： 10195
# 页数： 10196
# 页数： 10197
# 页数： 10198
# 页数： 10199
# 页数： 10200
# 页数： 10201
# 页数： 10202
# 页数： 10203
# 页数： 10204
# 页数： 10205
# 页数： 10206
# 页数： 10207
# 页数： 10208
# 页数： 10209
# 页数： 10210
# 页数： 10211
# 页数： 10212
# 页数： 10213
# 页数： 10214
# 页数： 10215
# 页数： 10216
# 页数： 10217
# 页数： 10218
# 页数： 10219
# 页数： 10220
# 页数： 10221
# 页数： 10222
# 页数： 10223
# 页数： 10224
# 页数： 10225
# 页数： 10226
# 页数： 10227
# 页数： 10228
# 页数： 10229
# 页数： 10230
# 页数： 10231
# 页数： 10232
# 页数： 10233
# 页数： 10234
# 页数： 10235
# 页数： 10236
# 页数： 10237
# 页数： 10238
# 页数： 10239
# 页数： 10240
# 页数： 10241
# 页数： 10242
# 页数： 10243
# 页数： 10244
# 页数： 10245
# 页数： 10246
# 页数： 10247
# 页数： 10248
# 页数： 10249
# 页数： 10250
# 页数： 10251
# 页数： 10252
# 页数： 10253
# 页数： 10254
# 页数： 10255
# 页数： 10256
# 页数： 10257
# 页数： 10258
# 页数： 10259
# 页数： 10260
# 页数： 10261
# 页数： 10262
# 页数： 10263
# 页数： 10264
# 页数： 10265
# 页数： 10266
# 页数： 10267
# 页数： 10268
# 页数： 10269
# 页数： 10270
# 页数： 10271
# 页数： 10272
# 页数： 10273
# 页数： 10274
# 页数： 10275
# 页数： 10276
# 页数： 10277
#
# url_model output:    http://college.gaokao.com/spepoint/y2011/p
# \pagenum output:    12426
# 页数： 9700
# 页数： 9701
# 页数： 9702
# 页数： 9703
# 页数： 9704
# 页数： 9705
# 页数： 9706
# 页数： 9707
# 页数： 9708
# 页数： 9709
# 页数： 9710
# 页数： 9711
# 页数： 9712
# 页数： 9713
# 页数： 9714
# 页数： 9715
# 页数： 9716
# 页数： 9717
# 页数： 9718
# 页数： 9719
# 页数： 9720
# 页数： 9721
# 页数： 9722
# 页数： 9723
# 页数： 9724
# 页数： 9725
# 页数： 9726
# 页数： 9727
# 页数： 9728
# 页数： 9729
# 页数： 9730
# 页数： 9731
# 页数： 9732
# 页数： 9733
# 页数： 9734
# 页数： 9735
# 页数： 9736
# 页数： 9737
# 页数： 9738
# 页数： 9739
# 页数： 9740
# 页数： 9741
# 页数： 9742
# 页数： 9743
# 页数： 9744
# 页数： 9745
# 页数： 9746
# 页数： 9747
# 页数： 9748
# 页数： 9749
# 页数： 9750
# 页数： 9751
# 页数： 9752
# 页数： 9753
# 页数： 9754
# 页数： 9755
# 页数： 9756
# 页数： 9757
# 页数： 9758
# 页数： 9759
# 页数： 9760
# 页数： 9761
# 页数： 9762
# 页数： 9763
# 页数： 9764
# 页数： 9765
# 页数： 9766
# 页数： 9767
# 页数： 9768
# 页数： 9769
# 页数： 9770
# 页数： 9771
# 页数： 9772
# 页数： 9773
# 页数： 9774
# 页数： 9775
# 页数： 9776
# 页数： 9777
# 页数： 9778
# 页数： 9779
# 页数： 9780
# 页数： 9781
# 页数： 9782
# 页数： 9783
# 页数： 9784
# 页数： 9785
# 页数： 9786
# 页数： 9787
# 页数： 9788
# 页数： 9789
# 页数： 9790
# 页数： 9791
# 页数： 9792
# 页数： 9793
# 页数： 9794
# 页数： 9795
# 页数： 9796
# 页数： 9797
# 页数： 9798
# 页数： 9799
# 页数： 9800
# 页数： 9801
# 页数： 9802
# 页数： 9803
# 页数： 9804
# 页数： 9805
# 页数： 9806
# 页数： 9807
# 页数： 9808
# 页数： 9809
# 页数： 9810
# 页数： 9811
# 页数： 9812
# 页数： 9813
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ba5559c76a3c> in <module>()
#      55                 school = None
#      56
# ---> 57             lav_score = s.xpath(xpath0+'['+str(j+2)+']'+avscorePath)
#      58             if len(lav_score)!=0:
#      59                 av_score = lav_score[0]
#
# src/lxml/etree.pyx in lxml.etree._Element.xpath()
#
# src/lxml/xpath.pxi in lxml.etree.XPathElementEvaluator.__call__()
#
# src/lxml/xpath.pxi in lxml.etree._XPathEvaluatorBase._handle_result()
#
# src/lxml/extensions.pxi in lxml.etree._unwrapXPathObject()
#
# src/lxml/extensions.pxi in lxml.etree._createNodeSetResult()
#
# src/lxml/extensions.pxi in lxml.etree._unpackNodeSetEntry()
#
# src/lxml/extensions.pxi in lxml.etree._buildElementStringResult()
#
# src/lxml/extensions.pxi in lxml.etree._elementStringResultFactory()
#
# KeyboardInterrupt:

# %%
#跑到完12年可停

# %%
print('a')

# %%
content2 = s.xpath('//*[@id="wrapper"]/div[1]/p[1]/a//@href')

# %%
print(content2)

# %%
r2= requests.get(content2[2])

# %%
html = r.text
s = etree.HTML(html)

# %%
data = s.xpath('//*[@id="wrapper"]/div[4]/ul/li[4]/a//@href')

# %%
print(data)
